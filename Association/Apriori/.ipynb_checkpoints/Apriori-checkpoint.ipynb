# %%
# !pip install apyori
# Out:
# ...
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5979 sha256=10a3019b7d4b8b8c2fe1f9beaa86f8acaca5c0677caad536937936bea3aa1410
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\1b\02\6c\a45230be8603bd95c0a51cd2b289aefdd860c1a100eab73661
# Successfully built apyori
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("./mb.csv",header=None)
data
# Out:
#                  0                  1            2                 3   \
# 0            shrimp            almonds      avocado    vegetables mix
# 1           burgers          meatballs         eggs               NaN
# 2           chutney                NaN          NaN               NaN
# 3            turkey            avocado          NaN               NaN
# 4     mineral water               milk   energy bar  whole wheat rice
# ...             ...                ...          ...               ...
# 7496         butter         light mayo  fresh bread               NaN
# 7497        burgers  frozen vegetables         eggs      french fries
# 7498        chicken                NaN          NaN               NaN
# 7499       escalope          green tea          NaN               NaN
# 7500           eggs    frozen smoothie  yogurt cake    low fat yogurt
#
#                 4                 5     6               7             8   \
# ...

# %%
data.shape
# Out:
# (7501, 20)

# %%
trans = []
for i in range(0,7501):
    trans.append([str(data.values[i,j]) for j in range(0,20)])

# %%
trans
# Out:
# [<generator object <genexpr> at 0x00000193CBC290B0>,
#  <generator object <genexpr> at 0x00000193CBC29190>,
#  <generator object <genexpr> at 0x00000193CBC29120>,
#  <generator object <genexpr> at 0x00000193CBC29200>,
#  <generator object <genexpr> at 0x00000193CBC29270>,
#  <generator object <genexpr> at 0x00000193CBC292E0>,
#  <generator object <genexpr> at 0x00000193CBC29350>,
#  <generator object <genexpr> at 0x00000193CBC293C0>,
#  <generator object <genexpr> at 0x00000193CBC29430>,
#  <generator object <genexpr> at 0x00000193CBC294A0>,
#  <generator object <genexpr> at 0x00000193CBC29510>,
#  <generator object <genexpr> at 0x00000193CBC29580>,
#  <generator object <genexpr> at 0x00000193CBC295F0>,
#  <generator object <genexpr> at 0x00000193CBC29660>,
#  <generator object <genexpr> at 0x00000193CBC296D0>,
#  <generator object <genexpr> at 0x00000193CBC29740>,
#  <generator object <genexpr> at 0x00000193CBC297B0>,
#  <generator object <genexpr> at 0x00000193CBC29820>,
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('./rr.tsv', delimiter = '\t', quoting = 3)

# %%
data
# Out:
#                                                 Review  Liked
# 0                             Wow... Loved this place.      1
# 1                                   Crust is not good.      0
# 2            Not tasty and the texture was just nasty.      0
# 3    Stopped by during the late May bank holiday of...      1
# 4    The selection on the menu was great and so wer...      1
# ..                                                 ...    ...
# 995  I think food should have flavor and texture an...      0
# 996                           Appetite instantly gone.      0
# 997  Overall I was not impressed and would not go b...      0
# 998  The whole experience was underwhelming, and I ...      0
# 999  Then, as if I hadn't wasted enough of my life ...      0
#
# [1000 rows x 2 columns]

# %% [markdown]
# Sentiment Analysis
#
# 1. Importing Libraries
# 2. Importing Datasets
# 3. Cleaning the Tests
# 4. Creating the bag of Words model
# 5. Splitting dataset as training and testing
# 6. Training with Classification algorithm
#     -> Naive Bayes Model
#     -> Logistic Regression
#     -> SVC - Support Vector Classification
#     -> Decision Tree
#     -> Random Forest
# 7. Confusion Matrix to evaluate the Training

# %% [markdown]
# Cleaning the Texts

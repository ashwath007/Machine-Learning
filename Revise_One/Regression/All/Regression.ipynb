# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("../Data/le.csv")
data.replace([np.inf, -np.inf], np.nan)
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015  Developing              65.0            263.0
# 1     Afghanistan  2014  Developing              59.9            271.0
# 2     Afghanistan  2013  Developing              59.9            268.0
# 3     Afghanistan  2012  Developing              59.5            272.0
# 4     Afghanistan  2011  Developing              59.2            275.0
# ...           ...   ...         ...               ...              ...
# 2933     Zimbabwe  2004  Developing              44.3            723.0
# 2934     Zimbabwe  2003  Developing              44.5            715.0
# 2935     Zimbabwe  2002  Developing              44.8             73.0
# 2936     Zimbabwe  2001  Developing              45.3            686.0
# 2937     Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# ...

# %%
def clean_dataset(df):
    assert isinstance(df, pd.DataFrame), "df needs to be a pd.DataFrame"
    df.dropna(inplace=True)
    indices_to_keep = ~df.isin([np.nan, np.inf, -np.inf]).any(1)
    return df[indices_to_keep].astype(np.float64)

# %%
data.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
data.describe
# Out:
# <bound method NDFrame.describe of           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015  Developing              65.0            263.0
# 1     Afghanistan  2014  Developing              59.9            271.0
# 2     Afghanistan  2013  Developing              59.9            268.0
# 3     Afghanistan  2012  Developing              59.5            272.0
# 4     Afghanistan  2011  Developing              59.2            275.0
# ...           ...   ...         ...               ...              ...
# 2933     Zimbabwe  2004  Developing              44.3            723.0
# 2934     Zimbabwe  2003  Developing              44.5            715.0
# 2935     Zimbabwe  2002  Developing              44.8             73.0
# 2936     Zimbabwe  2001  Developing              45.3            686.0
# 2937     Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# ...

# %%
data = data.reset_index()

# %% [markdown]
# 1. Linear Regression
# 2. Muliple Regression
# 3. Polynomial Regression
# 4. SVR Support vector Regression
# 5. Decision Tree
# 6. Random Forest Regression
# 7. Lasso Regression
# 8. Logistic Regression

# %% [markdown]
# Linear Regression

# %%
from sklearn.preprocessing import OneHotEncoder,StandardScaler,LabelEncoder

# %%
sc = LabelEncoder()
data['Country'] = sc.fit_transform(data['Country'])
data['Status'] = sc.fit_transform(data['Status'])

# %% [markdown]
# Data Preprocessing

# %% [markdown]
# 1. Encoding [Country] - Using One-Hot Encoding

# %%
data['Country']
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#        ...
# 2933    192
# 2934    192
# 2935    192
# 2936    192
# 2937    192
# Name: Country, Length: 2938, dtype: int32

# %%
data['Status']
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 2933    1
# 2934    1
# 2935    1
# 2936    1
# 2937    1
# Name: Status, Length: 2938, dtype: int32

# %%
data['Adult Mortality'].isnull().values.any()
# Out:
# True

# %%
data['Adult Mortality'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2933    False
# 2934    False
# 2935    False
# 2936    False
# 2937    False
# Name: Adult Mortality, Length: 2938, dtype: bool

# %%
data['Adult Mortality'].mean()
# Out:
# 164.79644808743168

# %%
clean_dataset(data)
# Out:
#        index  Country    Year  Status  Life expectancy   Adult Mortality  \
# 0        0.0      0.0  2015.0     1.0              65.0            263.0
# 1        1.0      0.0  2014.0     1.0              59.9            271.0
# 2        2.0      0.0  2013.0     1.0              59.9            268.0
# 3        3.0      0.0  2012.0     1.0              59.5            272.0
# 4        4.0      0.0  2011.0     1.0              59.2            275.0
# ...      ...      ...     ...     ...               ...              ...
# 2933  2933.0    192.0  2004.0     1.0              44.3            723.0
# 2934  2934.0    192.0  2003.0     1.0              44.5            715.0
# 2935  2935.0    192.0  2002.0     1.0              44.8             73.0
# 2936  2936.0    192.0  2001.0     1.0              45.3            686.0
# 2937  2937.0    192.0  2000.0     1.0              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  ...  Polio  \
# ...

# %%
from sklearn.impute import SimpleImputer
imp = SimpleImputer(missing_values=np.nan,strategy='mean')

# %%
X = data.iloc[:,1:8].values
y = data.iloc[:,-1].values

# %%
def encode(n):
    imp.fit(X[:,n:n+1])
    X[:,n:n+1] = imp.transform(X[:,n:n+1])

# %%
encode(1)

# %%
def checknan(n):
    ok = np.isnan(X[:,n:n+1])
    for i in ok:
        if i == True:
            print("RED")
            break
        else:
            print(i)

# %%
encode(3)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

# %%
np.isnan(X_train.any()) #and gets False
# Out:
# False

# %%
from sklearn.linear_model import LinearRegression
l_reg = LinearRegression()
l_reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = l_reg.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,r2_score,mean_absolute_error
r2_score(y_test,y_pred)
# Out:
# 0.697465171160697

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 1.2180984479342238
